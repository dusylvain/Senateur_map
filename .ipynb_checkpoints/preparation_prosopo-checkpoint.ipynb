# %%
#!pip install -q lxml
#!pip install unidecode
import pandas as pd
import numpy as np
#import geopandas as gpd
import urllib#pour récupérer les données
import bs4#pour rendre lisibles les données
import lxml
import re
import time
from unidecode import unidecode
import urllib

from urllib import request

# %%
def Scrap (url):
    req = urllib.request.Request(url)
    html = urllib.request.urlopen(req).read()
    page = bs4.BeautifulSoup(html, "lxml")
    return page

# %%
def ToDf (table) :
    Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
    listeDf=Listgrossiere[0]#on récupère le dataframe
    return listeDf

# %%
page=Scrap('https://fr.wikipedia.org/wiki/Liste_des_noms_fran%C3%A7ais_des_villes_europ%C3%A9ennes')

# %%
tables = page.findAll('table')
table = tables[0]
liste=ToDf(table)
listelien=[]
#for i in range(32):
#    page=Scrap('http://www2.assemblee-nationale.fr/sycomore/resultats/(offset)/'+str((i+1)*500)+'/(query)...')
table = page.find('table')#on récupère le seul tableau de la page qui liste des députés
listeDf=ToDf(table)
liste=pd.concat([liste,listeDf])#on récupère le dataframe et on l'ajoute à la liste  
for ele in table.findAll('a'):
    listelien.append(ele.get('href'))
liste=liste.reset_index()#on recrée un index afin de ne pas s'arrêter à 500 puis recommencer comme dans les pages web
# Out:
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes

# %%
page_dep=Scrap('https://fr.wikipedia.org/wiki/Liste_des_d%C3%A9partements_fran%C3%A7ais')
tables = page_dep.findAll('table')
table = tables[1]
liste_dep=ToDf(table)
liste_dep = liste_dep.droplevel(level = [0, 1], axis = 1)
listelien=[]
#for i in range(32):
#    page=Scrap('http://www2.assemblee-nationale.fr/sycomore/resultats/(offset)/'+str((i+1)*500)+'/(query)...')
table = page_dep.find('table')#on récupère le seul tableau de la page qui liste des députés
listeDf=ToDf(table)
liste_dep=pd.concat([liste_dep,listeDf])#on récupère le dataframe et on l'ajoute à la liste  
for ele in table.findAll('a'):
    listelien.append(ele.get('href'))
liste_dep=liste_dep.reset_index()
# Out:
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes

# %%
simplif = re.compile("\w+")

# %%
def simplifie(x):
    return simplif.match(x).group()
def unifie(x):
    return x.split("/")[0]

# %%
tables = page.findAll('table')
DF_tot = pd.DataFrame()
for table in tables:
    new_df = ToDf(table)
    new_df.columns = ["Nom local", "Nom en francais"]
    DF_tot=pd.concat([DF_tot,new_df])
# Out:
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes
# C:\Users\sylva\AppData\Local\Temp\ipykernel_14416\2293486399.py:2: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   Listgrossiere=pd.read_html(str(table))#on transforme le tableau en liste de dataframes

# %%
DF_tot.columns = ["Nom local", "Nom en francais"]
DF_tot["Nom en francais"] = DF_tot["Nom en francais"].apply(simplifie)
DF_tot["Nom local"] = DF_tot["Nom local"].apply(unifie)
DF_tot
# Out:
#              Nom local Nom en francais
# 0              Butrint       Bouthrote
# 1               Durrës        Épidamne
# 2                Korçë         Koritza
# 3              Shkodër         Scutari
# 4               Vlorë           Valone
# ..                 ...             ...
# 13         Tcherkassy        Tcherkass
# 14         Tchernihiv       Tchernikow
# 15         Tchyhyryne         Tcherine
# 16       Tchystiakove           Thorez
# 0   Città del Vaticano            Cité
#
# [750 rows x 2 columns]

# %%
Df_dep = liste_dep[["Nom", "Chef-lieu"]].dropna()

# %%
for column in Df_dep.columns:
    Df_dep[column] = Df_dep[column].apply(simplifie)

# %%
Df_dep = Df_dep[:99]
Df_dep = Df_dep.rename(columns = {"Nom": "Nom en francais", "Chef-lieu":"Nom local"})
Df_dep
# Out:
#    Nom en francais Nom local
# 0              Ain     Bourg
# 1            Aisne      Laon
# 2           Allier   Moulins
# 3            Alpes     Digne
# 4           Hautes       Gap
# ..             ...       ...
# 94             Val   Créteil
# 95             Val  Pontoise
# 97      Guadeloupe     Basse
# 98      Martinique      Fort
# 99          Guyane   Cayenne
#
# [99 rows x 2 columns]

# %%
Noms_speciaux = {"Allemagne":"Berlin", "Espagne":"Madrid", "Italie":"Roma", "Aix":"Aix-en-Provence"}
Df_special = pd.DataFrame.from_dict(Noms_speciaux, orient = "index").reset_index()
Df_special.columns = ["Nom en francais", "Nom local"]

# %%
Df_special
# Out:
#   Nom en francais        Nom local
# 0       Allemagne           Berlin
# 1         Espagne           Madrid
# 2          Italie             Roma
# 3             Aix  Aix-en-Provence

# %%
#DF_tot2 = 
DF_tot2 = DF_tot.loc[~(DF_tot["Nom en francais"].isin(Noms_speciaux.keys())),:]
DF_tot2 = pd.concat([DF_tot2, Df_special, Df_dep]).reset_index()
# del DF_tot2["index"]

# %%
DF_tot2
# Out:
#      index Nom local Nom en francais
# 0        0   Butrint       Bouthrote
# 1        1    Durrës        Épidamne
# 2        2     Korçë         Koritza
# 3        3   Shkodër         Scutari
# 4        4    Vlorë           Valone
# ..     ...       ...             ...
# 847     94   Créteil             Val
# 848     95  Pontoise             Val
# 849     97     Basse      Guadeloupe
# 850     98      Fort      Martinique
# 851     99   Cayenne          Guyane
#
# [852 rows x 3 columns]

# %%
DF_tot2[DF_tot2["Nom en francais"]=="Aix"]
# Out:
#      index        Nom local Nom en francais
# 752      3  Aix-en-Provence             Aix

# %%
senateur = pd.read_csv("C:/Users/sylva/OneDrive/Bureau/senat/Data/test_17_senateurs.csv")

# %%
years = list(range(1789, 1816))

# %%
def set_place_at_year(personne, year=1800):
    if year < 1789:
        period = "AR"
        nb_period_max = 1
    if 1788 < year < 1799:
        period = "Revolution"
        nb_period_max = 10
    if 1798 < year < 1805:
        period = "Consulat"
        nb_period_max = 5
    if 1804 < year < 1816:
        period = "Empire"
        nb_period_max = 7
    for num_period in range(1, nb_period_max):
        date_num = personne["Date "+period+" "+str(num_period)]
        if date_num == str(date_num):
            if int(year) in [int(date) for date in date_num.replace("/", "-").split("-")]:
                date_num = year
            else:
                date_num = 0
        if pd.notna(date_num) and int(date_num)==int(year):
            lieu = personne["Lieu "+period+" "+str(num_period)]
            if (type(lieu)==str) & (lieu != "paris"):
                return personne["Lieu "+period+" "+str(num_period)].title()
    return "Paris"

# %%
for year in years:
    senateur[year] = senateur.apply(set_place_at_year, axis = 1, args = [year])

# %%
senateur[1796]
# Out:
# 0                    Paris
# 1                    Paris
# 2                    Paris
# 3                    Paris
# 4                  Espagne
# 5                    Paris
# 6                    Paris
# 7                    Paris
# 8                    Paris
# 9                    Paris
# 10                   Paris
# 11             Montmorency
# 12    Campagnes Etrangeres
# 13                   Paris
# 14                   Paris
# 15                   Paris
# 16                   Paris
# Name: 1796, dtype: object

# %%
senateur["position_sociale"]=senateur["1. place hiérarchie sociale famille"]

# %%
def to_nom_unique(x, year):
    if x["Nom local"] == str(x["Nom local"]):
        return x["Nom local"]
    else:
        return x[year]

# %%
years
for year in years:
    senateur = pd.merge(senateur, DF_tot2, left_on = year, right_on = "Nom en francais", how = 'left')
    senateur["nom_local"+str(year)] = senateur.apply(to_nom_unique, axis = 1, args = [year])
    del senateur["Nom local"]
    del senateur["Nom en francais"]
# Out:
# ---------------------------------------------------------------------------
# MergeError                                Traceback (most recent call last)
# Cell In[26], line 3
#       1 years
#       2 for year in years:
# ----> 3     senateur = pd.merge(senateur, DF_tot2, left_on = year, right_on = "Nom en francais", how = 'left')
#       4     senateur["nom_local"+str(year)] = senateur.apply(to_nom_unique, axis = 1, args = [year])
#       5     del senateur["Nom local"]
#
# File ~\anaconda3\envs\senateur\Lib\site-packages\pandas\core\reshape\merge.py:184, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     169 else:
#     170     op = _MergeOperation(
#     171         left_df,
#     172         right_df,
#    (...)
#     182         validate=validate,
#     183     )
# --> 184     return op.get_result(copy=copy)
#
# File ~\anaconda3\envs\senateur\Lib\site-packages\pandas\core\reshape\merge.py:888, in _MergeOperation.get_result(self, copy)
#     884     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     886 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 888 result = self._reindex_and_concat(
#     889     join_index, left_indexer, right_indexer, copy=copy
#     890 )
#     891 result = result.__finalize__(self, method=self._merge_type)
#     893 if self.indicator:
#
# File ~\anaconda3\envs\senateur\Lib\site-packages\pandas\core\reshape\merge.py:840, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     837 left = self.left[:]
#     838 right = self.right[:]
# --> 840 llabels, rlabels = _items_overlap_with_suffix(
#     841     self.left._info_axis, self.right._info_axis, self.suffixes
#     842 )
#     844 if left_indexer is not None and not is_range_indexer(left_indexer, len(left)):
#     845     # Pinning the index here (and in the right code just below) is not
#     846     #  necessary, but makes the `.take` more performant if we have e.g.
#     847     #  a MultiIndex for left.index.
#     848     lmgr = left._mgr.reindex_indexer(
#     849         join_index,
#     850         left_indexer,
#    (...)
#     855         use_na_proxy=True,
#     856     )
#
# File ~\anaconda3\envs\senateur\Lib\site-packages\pandas\core\reshape\merge.py:2757, in _items_overlap_with_suffix(left, right, suffixes)
#    2755     dups.extend(rlabels[(rlabels.duplicated()) & (~right.duplicated())].tolist())
#    2756 if dups:
# -> 2757     raise MergeError(
#    2758         f"Passing 'suffixes' which cause duplicate columns {set(dups)} is "
#    2759         f"not allowed.",
#    2760     )
#    2762 return llabels, rlabels
#
# MergeError: Passing 'suffixes' which cause duplicate columns {'index_x'} is not allowed.

# %%
senateur

# %%
DF_tot2[DF_tot2["Nom en francais"]=="Aix"]
# Out:
#            Nom local Nom en francais
# 5             Aachen             Aix
# 753  Aix-en-Provence             Aix

# %%
pd.merge(senateur, DF_tot2, left_on = 1799, right_on = "Nom en francais", how = 'left')
# Out:
#      n°                      nom  \
# 0    66                 crassous
# 1    67                   colaud
# 2    68                 tronchet
# 3    69                 harville
# 4    70                 perignon
# 5    71                 gregoire
# 6    72  fabre de la martilliere
# 7    73                demeunier
# 8    76                   abrial
# 9    77                 aboville
# 10   78                   belloy
# 11   79                   fouche
# 12   79                   fouche
# 13   79                   fouche
# 14   79                   fouche
# 15  131                  ordener
# 16  132                   petiet
# 17  133                   barral
# 18  134                   primat
# 19  136                 arenberg
#
#    lieu naiss utile que pour appartenance juridique territoire "nationalité"  \
# 0                                         Montpellier
# 1                                            Briançon
# 2                                               Paris
# 3                                               Paris
# 4                             Grenade (près toulouse)
# 5                                     Vého, Lunéville
# 6                                               Nîmes
# 7                                             Nozeroy
# 8                                            Annonnay
# 9                                               Brest
# 10                                          Morangles
# 11                                             Nantes
# 12                                             Nantes
# 13                                             Nantes
# 14                                             Nantes
# 15                                        saint-avold
# 16                               chatillon sur seine
# 17                                           grenoble
# 18                                               lyon
# 19                                          bruxelles
#
#              dpt rev nat = par zone plutôt (dpt)  date naiss  date nomin  \
# 0            herault                    français  07/08/1946  18/01/2001
# 1       hautes-alpes                    français  11/12/1954  13/02/2001
# 2              seine                    français  23/03/1926  27/02/2001
# 3              seine                    français  23/04/1947  12/03/2001
# 4      haute garonne                    français  31/05/1954  29/03/2001
# 5                NaN                    français  04/12/1950  25/12/2001
# 6               gard                    français  10/03/1932  04/01/2002
# 7               jura                    français  15/03/1951  18/01/2002
# 8            ardeche                    français  19/03/1950  14/09/2002
# 9          finistere                    français  23/01/1930  14/09/2002
# 10              oise                    français  19/10/1909  14/09/2002
# 11  loire inferieure                    français  19/09/1954  14/09/2002
# 12  loire inferieure                    français  19/09/1954  14/09/2002
# 13  loire inferieure                    français  19/09/1954  14/09/2002
# 14  loire inferieure                    français  19/09/1954  14/09/2002
# 15           moselle                    français    02/09/55    19/05/06
# 16         cote-d'or                    français    09/02/49    19/05/06
# 17             isere                    français    20/04/46    19/05/06
# 18       rhone-alpes                    français    26/07/47    19/05/06
# 19              dyle                  bruxellois    03/08/50    19/05/06
#
#     date deces  age revol  age nomin  ...  nom_local1808    nom_local1809  \
# 0   10/09/2001         42         54  ...          Paris            Paris
# 1   03/12/2019         34         46  ...          Paris        Antwerpen
# 2   10/03/2006         63         74  ...          Paris            Paris
# 3   08/05/2015         42         53  ...          Paris            Paris
# 4   25/12/2018         34         46  ...         Napoli            Paris
# 5   04/12/2031         38         51  ...          Paris            Paris
# 6   27/03/2019         57         69  ...          Paris            Paris
# 7   07/02/2014         38         50  ...          Paris            Paris
# 8   13/11/2028         39         52  ...           Roma            Paris
# 9   01/11/2017         59         72  ...          Paris  Anvers Belgique
# 10  10/06/2008         79         92  ...          Paris            Paris
# 11  25/12/2020         34         47  ...          Paris            Paris
# 12  25/12/2020         34         47  ...          Paris            Paris
# 13  25/12/2020         34         47  ...          Paris            Paris
# 14  25/12/2020         34         47  ...          Paris            Paris
# 15    30/08/11         33         50  ...          Paris            Paris
# 16    25/05/06         40         57  ...          Paris            Paris
# 17    06/06/16         43         60  ...          Paris           Savona
# 18    10/10/16         41         58  ...          Paris            Paris
# 19    06/03/20         38         55  ...          Paris            Paris
#
#       nom_local1810 nom_local1811  nom_local1812 nom_local1813 nom_local1814  \
# 0             Paris         Paris          Paris         Paris         Paris
# 1             Paris         Paris          Paris         Paris         Paris
# 2             Paris         Paris          Paris         Paris         Paris
# 3             Paris         Paris          Paris         Paris         Paris
# 4             Paris         Paris          Paris         Paris         Paris
# 5             Paris         Paris          Paris         Paris         Paris
# 6             Paris         Paris          Paris         Paris         Paris
# 7             Paris         Paris          Paris         Paris         Paris
# 8             Paris         Paris          Paris         Paris         Paris
# 9             Paris         Paris          Paris         Paris         Paris
# 10            Paris         Paris          Paris         Paris         Paris
# 11           Aachen         Paris          Paris     Ljubljana          Lyon
# 12  Aix-en-Provence         Paris          Paris     Ljubljana          Lyon
# 13           Aachen         Paris          Paris     Ljubljana          Lyon
# 14  Aix-en-Provence         Paris          Paris     Ljubljana          Lyon
# 15            Paris         Paris          Paris         Paris         Paris
# 16            Paris         Paris          Paris         Paris         Paris
# 17            Paris        Savona  Fontainebleau         Paris         Paris
# 18            Paris         Paris          Paris         Paris         Paris
# 19            Paris         Paris          Paris         Paris         Paris
#
#     nom_local1815 Nom local Nom en francais
# 0           Paris     Paris           Paris
# 1           Paris     Paris           Paris
# 2           Paris     Paris           Paris
# 3           Paris     Paris           Paris
# 4           Paris     Paris           Paris
# 5           Paris     Paris           Paris
# 6           Paris     Paris           Paris
# 7           Paris     Paris           Paris
# 8           Paris    Napoli          Naples
# 9           Paris     Paris           Paris
# 10          Paris     Paris           Paris
# 11          Paris     Paris           Paris
# 12          Paris     Paris           Paris
# 13          Paris     Paris           Paris
# 14          Paris     Paris           Paris
# 15          Paris     Paris           Paris
# 16          Paris     Paris           Paris
# 17          Paris     Paris           Paris
# 18          Paris     Paris           Paris
# 19          Paris     Paris           Paris
#
# [20 rows x 222 columns]

# %%
senateur_for_map = senateur[["nom_local"+str(year) for year in years]+["position_sociale"]]

# %%
senateur_for_map.to_csv("C:/Users/sylva/OneDrive/Bureau/senat/Data/senateur_for_map.csv")

# %%
senateur_for_map
# Out:
#    nom_local1789   nom_local1790        nom_local1791         nom_local1792  \
# 0          Paris         Herault                Paris                 Paris
# 1          Paris           Paris                Paris                 Valmy
# 2          Paris           Paris                Paris                 Paris
# 3          Paris           Paris                Paris              Jemmapes
# 4        Montech           Paris  Pyrenees-Orientales                 Paris
# 5          Paris           Blois         Loir Et Cher                 Paris
# 6          Douai           Paris                Paris   Pyrenees-Orientales
# 7          Paris           Paris                Paris            Etats-Unis
# 8          Paris           Paris                Paris                 Paris
# 9          Paris           Paris                Paris                 Valmy
# 10         Paris           Paris       Chambly (Oise)                 Paris
# 11         Paris           Paris                Paris                France
# 12         Paris           Paris                Paris  Campagnes Etrangeres
# 13         Paris  Ile Et Vilaine                Paris                 Paris
# 14         Paris          Troyes                Paris                 Paris
# 15         Paris           Paris              Cambrai                 Paris
# 16     Bruxelles       Bruxelles                Paris                  Roma
#
#              nom_local1793                             nom_local1794  \
# 0                    Paris                                     Paris
# 1            Armée Du Nord                            Trèves Mayence
# 2                    Paris                                     Paris
# 3                    Paris                          Sambre Et Mesuse
# 4                Perpignan                       Pyrénées Orientales
# 5               Mont-Blanc                                     Paris
# 6                    Paris                                 Catalogne
# 7                    Paris                                     Paris
# 8                    Paris                                     Paris
# 9                 Soissons  Valenciennes Condé Landrecies Le Quesnoy
# 10                   Paris                                     Paris
# 11                    Lyon                                     Paris
# 12            Moselle Rhin                      Campagnes Etrangeres
# 13                  Nantes                                     Paris
# 14  Suisse Puis Angleterre                                     Paris
# 15                   Paris                                     Paris
# 16                   Paris                                    Berlin
#
#    nom_local1795         nom_local1796 nom_local1797 nom_local1798  ...  \
# 0          Paris                 Paris         Paris         Paris  ...
# 1         Toulon                 Paris      Siegberg      Belgique  ...
# 2          Paris                 Paris         Paris         Paris  ...
# 3    Sur Le Mein                 Paris         Paris         Paris  ...
# 4          Paris                Madrid         Paris          Roma  ...
# 5          Paris                 Paris         Paris         Paris  ...
# 6          Paris                 Paris         Paris         Paris  ...
# 7          Paris                 Paris         Paris         Paris  ...
# 8          Paris                 Paris         Paris         Paris  ...
# 9          Paris                 Paris         Paris         Paris  ...
# 10         Paris                 Paris         Paris         Paris  ...
# 11        Madrid           Montmorency         Paris         Paris  ...
# 12         Paris  Campagnes Etrangeres         Paris         Paris  ...
# 13         Paris                 Paris         Paris         Paris  ...
# 14         Paris                 Paris         Paris         Paris  ...
# 15         Paris                 Paris         Lille          Lyon  ...
# 16         Paris                 Paris         Paris         Paris  ...
#
#    nom_local1807 nom_local1808    nom_local1809    nom_local1810  \
# 0          Paris         Paris            Paris            Paris
# 1          Paris         Paris        Antwerpen            Paris
# 2          Paris         Paris            Paris            Paris
# 3          Paris         Paris            Paris            Paris
# 4          Paris        Napoli            Paris            Paris
# 5          Paris         Paris            Paris            Paris
# 6          Paris         Paris            Paris            Paris
# 7          Paris         Paris            Paris            Paris
# 8          Paris          Roma            Paris            Paris
# 9          Brest         Paris  Anvers Belgique            Paris
# 10         Paris         Paris            Paris            Paris
# 11         Paris         Paris            Paris  Aix-en-Provence
# 12         Paris         Paris            Paris            Paris
# 13         Paris         Paris            Paris            Paris
# 14         Paris         Paris           Savona            Paris
# 15         Paris         Paris            Paris            Paris
# 16         Paris         Paris            Paris            Paris
#
#    nom_local1811  nom_local1812 nom_local1813 nom_local1814 nom_local1815  \
# 0          Paris          Paris         Paris         Paris         Paris
# 1          Paris          Paris         Paris         Paris         Paris
# 2          Paris          Paris         Paris         Paris         Paris
# 3          Paris          Paris         Paris         Paris         Paris
# 4          Paris          Paris         Paris         Paris         Paris
# 5          Paris          Paris         Paris         Paris         Paris
# 6          Paris          Paris         Paris         Paris         Paris
# 7          Paris          Paris         Paris         Paris         Paris
# 8          Paris          Paris         Paris         Paris         Paris
# 9          Paris          Paris         Paris         Paris         Paris
# 10         Paris          Paris         Paris         Paris         Paris
# 11         Paris          Paris     Ljubljana          Lyon         Paris
# 12         Paris          Paris         Paris         Paris         Paris
# 13         Paris          Paris         Paris         Paris         Paris
# 14        Savona  Fontainebleau         Paris         Paris         Paris
# 15         Paris          Paris         Paris         Paris         Paris
# 16         Paris          Paris         Paris         Paris         Paris
#
#          position_sociale
# 0                   droit
# 1                  négoce
# 2                   droit
# 3                noblesse
# 4                noblesse
# 5                 artisan
# 6                   droit
# 7                  paysan
# 8                     NaN
# 9             haute armée
# 10            haute armée
# 11                 négoce
# 12                    NaN
# 13              magistrat
# 14              magistrat
# 15                 faible
# 16  haute admin province
#
# [17 rows x 28 columns]
